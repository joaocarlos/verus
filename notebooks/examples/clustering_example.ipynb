# %% [markdown]
# # VERUS Clustering
#
# This example demonstrate the clustering process within VERUS following the steps below:
#
# 1. Load the data
# 2. Extract initial centers using OPTICS
# 3. Cluster the data with KMeans using the VI as weights
# 4. Visualize the clusters

# %%
from verus.clustering import GeOPTICS, KMeansHaversine
import pandas as pd

# %% [markdown]
# ## 1. Load Data
#
# For this example, the data is loaded from a dataset.

# %%
poi_data = pd.read_csv("../../data/poti/Porto_dataset_buffered.csv")

# %% [markdown]
# ## 2. Run OPTICS clustering to obtain initial centers

# %%
optics = GeOPTICS(min_samples=5, xi=0.05, min_cluster_size=5, verbose=True)
optics_results = optics.run(data_source=poi_data)
# Out:
# 2025-03-13 17:55:44 [INFO] Using provided DataFrame
# 2025-03-13 17:55:44 [INFO] Loaded 486 points of interest
# 2025-03-13 17:55:44 [INFO] Running OPTICS clustering on 486 points
# 2025-03-13 17:55:44 [INFO] Using epsilon: 0.00018835321652671395 radians
# 2025-03-13 17:55:44 [INFO] Assigning noise points to nearest clusters using KNN
# 2025-03-13 17:55:44 [INFO] Found 31 clusters

# %% [markdown]
# ### 2.1 Visualize the OPTICS clustering results

# %%
optics.view(cluster_df=optics_results["clusters"], centroids_df=optics_results["centroids"])
# Out:
# 2025-03-13 17:55:44 [INFO] Creating interactive map
# 2025-03-13 17:55:44 [INFO] Adding cluster points to map
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6485a8dfc0eb5d8c657721e593942f2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6485a8dfc0eb5d8c657721e593942f2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6485a8dfc0eb5d8c657721e593942f2c = L.map(
#                 &quot;map_6485a8dfc0eb5d8c657721e593942f2c&quot;,
#                 {
#                     center: [41.15878755070063, -8.62208162798831],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_609ffcaa5740b679ecc2a43489f65641 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_609ffcaa5740b679ecc2a43489f65641.addTo(map_6485a8dfc0eb5d8c657721e593942f2c);
#
#
#             var feature_group_263abbe8aefc6d544c25fcb09ac03221 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_c24af86b579d0a28c5f6bbe0b8513460 = L.circleMarker(
#                 [41.1481141, -8.6062129],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#440154ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#440154ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(feature_group_263abbe8aefc6d544c25fcb09ac03221);
#
#
#         var popup_f1320a49bc36422dcb3f6cb08ac5af30 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_4c627edb85ddde64b3581a500590a165 = $(`&lt;div id=&quot;html_4c627edb85ddde64b3581a500590a165&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                 &lt;b&gt;Colégio Dom Dinis - Pólo de Santa Catarina&lt;/b&gt;&lt;br&gt;                 Category: school                 &lt;br&gt;Vulnerability Index: 0.0&lt;/div&gt;`)[0];
#                 popup_f1320a49bc36422dcb3f6cb08ac5af30.setContent(html_4c627edb85ddde64b3581a500590a165);
#
#
#
#         circle_marker_c24af86b579d0a28c5f6bbe0b8513460.bindPopup(popup_f1320a49bc36422dcb3f6cb08ac5af30)
#         ;
#
#
#
#
#             circle_marker_c24af86b579d0a28c5f6bbe0b8513460.bindTooltip(
#                 `&lt;div&gt;
#                      Cluster 0: school
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_effdc97d9f7fd5fc3b84e9e3c843d548 = L.circleMarker(
#                 [41.1518816, -8.6035345],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#440154ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#440154ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(feature_group_263abbe8aefc6d544c25fcb09ac03221);
#
#
#         var popup_c85c56810b4dfb6dac9651967f84b457 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_7d6814a2447ed697fbf263a34b2576db = $(`&lt;div id=&quot;html_7d6814a2447ed697fbf263a34b2576db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                 &lt;b&gt;InDance Academia de Artes&lt;/b&gt;&lt;br&gt;                 Category: school                 &lt;br&gt;Vulnerability Index: 0.0&lt;/div&gt;`)[0];
#                 popup_c85c56810b4dfb6dac9651967f84b457.setContent(html_7d6814a2447ed697fbf263a34b2576db);
#
#
#
#         circle_marker_effdc97d9f7fd5fc3b84e9e3c843d548.bindPopup(popup_c85c56810b4dfb6dac9651967f84b457)
#         ;
#
#
#
#
#             circle_marker_effdc97d9f7fd5fc3b84e9e3c843d548.bindTooltip(
#                 `&lt;div&gt;
#                      Cluster 0: school
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_1007e74788feec0ea214128f689f0015 = L.circleMarker(
#                 [41.1488817, -8.6059873],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#440154ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#440154ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;

# %% [markdown]
# ## 3. Use OPTICS centers to initialize KMeans

# %%
if optics_results["centroids"] is not None and len(optics_results["centroids"]) > 1:
    centers = optics_results["centroids"]
    print(f"Running KMeans with {len(centers)} OPTICS centers")

    kmeans = KMeansHaversine(
        n_clusters=len(centers),
        init="predefined",
        random_state=42,
        predefined_centers=centers,
    )

    kmeans_results = kmeans.run(data_source=poi_data, centers_input=centers)

    # Access clustering results
    clusters = kmeans_results["clusters"]
    centroids = kmeans_results["centroids"]

    print(f"Found {len(centroids)} clusters")
    print(f"Cluster distribution:\n{clusters['cluster'].value_counts()}")
# Out:
# Running KMeans with 31 OPTICS centers
# 2025-03-13 17:55:44 [INFO] Using provided DataFrame
# 2025-03-13 17:55:44 [INFO] Loaded 486 points of interest
# 2025-03-13 17:55:44 [INFO] Using provided DataFrame with 31 centers
# 2025-03-13 17:55:44 [INFO] Using vulnerability indices as sample weights
# 2025-03-13 17:55:44 [INFO] Starting K-means clustering with 31 clusters
# 2025-03-13 17:55:44 [INFO] Using predefined initialization method
# 2025-03-13 17:55:44 [INFO] Using predefined centroids
# 2025-03-13 17:55:44 [INFO] K-means iteration 1/300
# 2025-03-13 17:55:44 [INFO] Maximum centroid shift: 0.244308 km
# 2025-03-13 17:55:44 [INFO] K-means iteration 2/300
# 2025-03-13 17:55:44 [INFO] Maximum centroid shift: 0.133866 km
# 2025-03-13 17:55:44 [INFO] K-means iteration 3/300
# 2025-03-13 17:55:44 [INFO] Maximum centroid shift: 0.148268 km
# 2025-03-13 17:55:44 [INFO] K-means iteration 4/300
# 2025-03-13 17:55:44 [INFO] Maximum centroid shift: 0.112348 km
# 2025-03-13 17:55:44 [INFO] K-means iteration 5/300
# 2025-03-13 17:55:44 [INFO] Maximum centroid shift: 0.127937 km
# 2025-03-13 17:55:44 [INFO] K-means iteration 6/300
# 2025-03-13 17:55:44 [INFO] Maximum centroid shift: 0.104279 km
# 2025-03-13 17:55:44 [INFO] K-means iteration 7/300
# 2025-03-13 17:55:44 [INFO] Maximum centroid shift: 0.061800 km
# 2025-03-13 17:55:44 [INFO] K-means iteration 8/300
# 2025-03-13 17:55:44 [INFO] Maximum centroid shift: 0.059047 km
# 2025-03-13 17:55:44 [INFO] K-means iteration 9/300
# 2025-03-13 17:55:44 [INFO] Maximum centroid shift: 0.101998 km
# 2025-03-13 17:55:44 [INFO] K-means iteration 10/300
# 2025-03-13 17:55:44 [INFO] Maximum centroid shift: 0.146923 km
# 2025-03-13 17:55:44 [INFO] K-means iteration 11/300
# 2025-03-13 17:55:44 [INFO] Maximum centroid shift: 0.031486 km
# 2025-03-13 17:55:44 [INFO] K-means iteration 12/300
# 2025-03-13 17:55:44 [INFO] Maximum centroid shift: 0.058256 km
# 2025-03-13 17:55:44 [INFO] K-means iteration 13/300
# 2025-03-13 17:55:44 [INFO] Maximum centroid shift: 0.057200 km
# 2025-03-13 17:55:44 [INFO] K-means iteration 14/300
# 2025-03-13 17:55:44 [INFO] Maximum centroid shift: 0.000000 km
# 2025-03-13 17:55:44 [SUCCESS] Converged after 14 iterations
# 2025-03-13 17:55:44 [SUCCESS] K-means completed with inertia: 0.0000
# Found 31 clusters
# Cluster distribution:
# cluster
# 3     23
# 11    22
# 21    21
# 7     21
# 19    21
# 9     20
# 12    18
# 13    18
# 1     18
# 29    17
# 26    17
# 6     17
# 18    16
# 8     16
# 15    16
# 20    16
# 22    15
# 24    14
# 0     14
# 27    14
# 10    14
# 28    14
# 16    14
# 25    14
# 14    14
# 23    12
# 17    12
# 2     11
# 30    10
# 4     10
# 5      7
# Name: count, dtype: int64

# %% [markdown]
# ### 3.1. Visualize the clusters

# %%
kmeans.view(clusters, centroids)
# Out:
# 2025-03-13 17:55:44 [INFO] Creating interactive map
# 2025-03-13 17:55:44 [INFO] Creating map with 31 clusters
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f5959703e0f85d2a60efc627f46e610 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f5959703e0f85d2a60efc627f46e610&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f5959703e0f85d2a60efc627f46e610 = L.map(
#                 &quot;map_5f5959703e0f85d2a60efc627f46e610&quot;,
#                 {
#                     center: [41.15878755070063, -8.62208162798831],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f623d808f0b26caabfd8cc464ec4e4b4 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f623d808f0b26caabfd8cc464ec4e4b4.addTo(map_5f5959703e0f85d2a60efc627f46e610);
#
#
#             var feature_group_17c94b9b20479ae91a67780d9db77e05 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_5d7430c43077c28411b5ae66b8a51674 = L.circleMarker(
#                 [41.1481141, -8.6062129],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#30123b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#30123b&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(feature_group_17c94b9b20479ae91a67780d9db77e05);
#
#
#         var popup_e0e250a43003834572e7274bbd0fd447 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_6514d914561d2f3c715e0365b9cdaaed = $(`&lt;div id=&quot;html_6514d914561d2f3c715e0365b9cdaaed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                     &lt;b&gt;Colégio Dom Dinis - Pólo de Santa Catarina&lt;/b&gt;&lt;br&gt;                     Category: school                     &lt;br&gt;VI: 0.0&lt;/div&gt;`)[0];
#                 popup_e0e250a43003834572e7274bbd0fd447.setContent(html_6514d914561d2f3c715e0365b9cdaaed);
#
#
#
#         circle_marker_5d7430c43077c28411b5ae66b8a51674.bindPopup(popup_e0e250a43003834572e7274bbd0fd447)
#         ;
#
#
#
#
#             circle_marker_5d7430c43077c28411b5ae66b8a51674.bindTooltip(
#                 `&lt;div&gt;
#                      Cluster 0: Colégio Dom Dinis - Pólo de Santa Catarina
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_fd00ef1da54ca0263967e7cd3d1e113b = L.circleMarker(
#                 [41.1488817, -8.6059873],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#30123b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#30123b&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(feature_group_17c94b9b20479ae91a67780d9db77e05);
#
#
#         var popup_a0bcfe91fde92d1988085ce942f5db72 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_e1aa59de64a3ee0e1daafe1615e3614a = $(`&lt;div id=&quot;html_e1aa59de64a3ee0e1daafe1615e3614a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                     &lt;b&gt;Escola de Yoga Antigo&lt;/b&gt;&lt;br&gt;                     Category: school                     &lt;br&gt;VI: 0.0&lt;/div&gt;`)[0];
#                 popup_a0bcfe91fde92d1988085ce942f5db72.setContent(html_e1aa59de64a3ee0e1daafe1615e3614a);
#
#
#
#         circle_marker_fd00ef1da54ca0263967e7cd3d1e113b.bindPopup(popup_a0bcfe91fde92d1988085ce942f5db72)
#         ;
#
#
#
#
#             circle_marker_fd00ef1da54ca0263967e7cd3d1e113b.bindTooltip(
#                 `&lt;div&gt;
#                      Cluster 0: Escola de Yoga Antigo
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_f51d222fc7a71045549afd2111c27ed5 = L.circleMarker(
#                 [41.1469846, -8.6054465],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#30123b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#30123b&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin
