# %% [markdown]
# # VERUS Quick Start
#
# This guide will help you get started with VERUS quickly.

# %%
from verus import VERUS
from verus.data import DataExtractor, TimeWindowGenerator
from verus.grid import HexagonGridGenerator

# %% [markdown]
# ## 1. Extract POI data

# %%
extractor = DataExtractor(region="Porto, Portugal")
poi_data = extractor.run()

# %%
extractor.view(poi_data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab2826c0ab856adf5b5ec2c9ee868ef3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab2826c0ab856adf5b5ec2c9ee868ef3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab2826c0ab856adf5b5ec2c9ee868ef3 = L.map(
#                 &quot;map_ab2826c0ab856adf5b5ec2c9ee868ef3&quot;,
#                 {
#                     center: [41.161690100750405, -8.620862974017003],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_833824bc865b39639ddbbb200a1eda91 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_833824bc865b39639ddbbb200a1eda91.addTo(map_ab2826c0ab856adf5b5ec2c9ee868ef3);
#
#
#         function geo_json_e47ceaffd05064e04852b45747807e0d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#808080&quot;, &quot;fillColor&quot;: &quot;#808080&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_e47ceaffd05064e04852b45747807e0d_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e47ceaffd05064e04852b45747807e0d = L.geoJson(null, {
#                 onEachFeature: geo_json_e47ceaffd05064e04852b45747807e0d_onEachFeature,
#
#                 style: geo_json_e47ceaffd05064e04852b45747807e0d_styler,
#             ...{
# }
#         });
#
#         function geo_json_e47ceaffd05064e04852b45747807e0d_add (data) {
#             geo_json_e47ceaffd05064e04852b45747807e0d
#                 .addData(data);
#         }
#             geo_json_e47ceaffd05064e04852b45747807e0d_add({&quot;bbox&quot;: [-8.691289, 41.1383507, -8.5519965, 41.1859353], &quot;features&quot;: [{&quot;bbox&quot;: [-8.691289, 41.1383507, -8.5519965, 41.1859353], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-8.691289, 41.1687516], [-8.6910583, 41.1687579], [-8.6911238, 41.1685915], [-8.6909954, 41.1686439], [-8.6909586, 41.1686264], [-8.6909354, 41.168463], [-8.6909951, 41.1684185], [-8.6909393, 41.1683946], [-8.6910808, 41.1683303], [-8.691083, 41.1683021], [-8.6909621, 41.1683554], [-8.6909104, 41.1683368], [-8.6908592, 41.1682624], [-8.6908112, 41.1682801], [-8.6907301, 41.1682415], [-8.6906942, 41.1682883], [-8.6905393, 41.1682527], [-8.690323, 41.168278], [-8.6902618, 41.1682271], [-8.6902697, 41.1680999], [-8.6905101, 41.1680877], [-8.6906964, 41.1680018], [-8.6906476, 41.1680029], [-8.6906568, 41.1679266], [-8.6905648, 41.1678992], [-8.6906586, 41.1678335], [-8.6905583, 41.1678514], [-8.6905191, 41.1678282], [-8.6906161, 41.1678194], [-8.6906192, 41.1677907], [-8.6905565, 41.1677978], [-8.6905231, 41.1677608], [-8.6904243, 41.1677691], [-8.690374, 41.1677446], [-8.6903409, 41.1677763], [-8.6902342, 41.1677695], [-8.6901709, 41.1676398], [-8.6902124, 41.1674475], [-8.6904271, 41.1670826], [-8.6903606, 41.1670471], [-8.6902655, 41.1670721], [-8.6902627, 41.1670125], [-8.690222, 41.1669868], [-8.690309, 41.1669036], [-8.6904438, 41.1669038], [-8.6905196, 41.1667492], [-8.6903444, 41.1668291], [-8.6904622, 41.1667135], [-8.6903828, 41.1666596], [-8.6903929, 41.1666069], [-8.6903336, 41.1665664], [-8.6902658, 41.1666089], [-8.6901627, 41.1665889], [-8.6901073, 41.1666581], [-8.689987, 41.1666345], [-8.6898719, 41.1666753], [-8.6900595, 41.1665056], [-8.6900458, 41.1664668], [-8.6899945, 41.1664599], [-8.6899302, 41.1665022], [-8.6899435, 41.1663851], [-8.6896519, 41.1664878], [-8.689603, 41.1664782], [-8.6895696, 41.1663521], [-8.6896251, 41.1663158], [-8.6897049, 41.1663447], [-8.6897173, 41.1662827], [-8.6896748, 41.1662297], [-8.6897574, 41.1661817], [-8.6898036, 41.1660889], [-8.689721, 41.1661243], [-8.6897052, 41.1661009], [-8.6895169, 41.1661115], [-8.6893784, 41.1661794], [-8.6893561, 41.1661679], [-8.689401, 41.1661371], [-8.6895393, 41.1660744], [-8.689419, 41.1660778], [-8.6893496, 41.1661024], [-8.6893161, 41.1661977], [-8.6892662, 41.16621], [-8.6892559, 41.1660775], [-8.6892083, 41.1660592], [-8.6891018, 41.1661008], [-8.689229, 41.1660084], [-8.689225, 41.1659888], [-8.6891741, 41.1660014], [-8.689172, 41.1659687], [-8.6890773, 41.1660339], [-8.6890628, 41.1659611], [-8.6891391, 41.165931], [-8.6891572, 41.1658877], [-8.6890585, 41.1659294], [-8.6890832, 41.1658612], [-8.6890137, 41.1659051], [-8.6890165, 41.1658086], [-8.6889154, 41.1658578], [-8.6888694, 41.1658473], [-8.6888642, 41.1657795], [-8.6889128, 41.165775], [-8.688918, 41.1657353], [-8.6887459, 41.1657232], [-8.6888234, 41.1655897], [-8.6887684, 41.1655424], [-8.6886761, 41.1655873], [-8.6885843, 41.1655518], [-8.6885222, 41.1654131], [-8.6885524, 41.1654006], [-8.6885348, 4

# %% [markdown]
# ## 2. Generate time windows

# %%
tw_gen = TimeWindowGenerator()
time_windows = tw_gen.generate_from_schedule()
# Out:
# 2025-03-13 16:30:55 [INFO] Using reference date: 2025-03-10
# 2025-03-13 16:30:55 [INFO] Loaded schedules for 9 POI types
# 2025-03-13 16:30:55 [INFO] Processing schedule for hospital
# 2025-03-13 16:30:55 [INFO] Created 17 time windows for hospital
# 2025-03-13 16:30:55 [INFO] Processing schedule for park
# 2025-03-13 16:30:55 [INFO] Created 7 time windows for park
# 2025-03-13 16:30:55 [INFO] Processing schedule for mall
# 2025-03-13 16:30:55 [INFO] Created 12 time windows for mall
# 2025-03-13 16:30:55 [INFO] Processing schedule for school
# 2025-03-13 16:30:55 [INFO] Created 10 time windows for school
# 2025-03-13 16:30:55 [INFO] Processing schedule for attraction
# 2025-03-13 16:30:55 [INFO] Created 7 time windows for attraction
# 2025-03-13 16:30:55 [INFO] Processing schedule for station
# 2025-03-13 16:30:55 [INFO] Created 15 time windows for station
# 2025-03-13 16:30:55 [INFO] Processing schedule for bus_station
# 2025-03-13 16:30:55 [INFO] Created 15 time windows for bus_station
# 2025-03-13 16:30:55 [INFO] Processing schedule for university
# 2025-03-13 16:30:55 [INFO] Created 10 time windows for university
# 2025-03-13 16:30:55 [INFO] Processing schedule for industrial
# 2025-03-13 16:30:55 [INFO] Created 5 time windows for industrial
# 2025-03-13 16:30:55 [INFO] Successfully generated time windows for 9 POI types

# %% [markdown]
# ## 4. Create hexagonal grid (Vulnerability Zones)

# %%
grid_gen = HexagonGridGenerator(region="Porto, Portugal", edge_length=250)
hex_grid = grid_gen.run()
# Out:
# 2025-03-13 16:30:55 [INFO] Initialized grid generator for Porto, Portugal with 250m edge length
# 2025-03-13 16:30:55 [INFO] Processing region: Porto, Portugal
# 2025-03-13 16:30:55 [INFO] Generating hexagonal grid with edge length 250m
# 2025-03-13 16:30:55 [INFO] Generated 740 hexagons
# 2025-03-13 16:30:55 [INFO] Assigning random values between 0 and 1
# 2025-03-13 16:30:55 [INFO] Assigning colors based on values
# 2025-03-13 16:30:55 [INFO] Clipping grid to region boundaries
# 2025-03-13 16:30:55 [INFO] Clipped from 740 to 514 hexagons

# %% [markdown]
# ## 4. Initialize vulnerability assessment

# %%
config = {
    "max_vulnerability": {"Porto": 0.0003476593149558199},
}
assessor = VERUS(place_name="Porto", config=config)
# Out:
# 2025-03-13 16:30:55 [INFO] VulnerabilityAssessor initialized for Porto using gaussian method

# %% [markdown]
# ## 5. Load data

# %%
assessor.load(
    potis_df=poi_data,
    time_windows_dict=time_windows,
    zones_gdf=hex_grid,
)
# Out:
# 2025-03-13 16:30:55 [WARNING] POTI DataFrame doesn't have 'cluster' column. Setting all to 0.
# 2025-03-13 16:30:55 [INFO] Loaded 487 POTIs
# 2025-03-13 16:30:55 [INFO] Loaded 514 vulnerability zones
# 2025-03-13 16:30:55 [INFO] Loaded time windows for 9 categories

# %% [markdown]
# ## 6. Run assessment

# %%
evaluation_time = tw_gen.to_unix_epoch("2025-03-13 17:30:00")
results = assessor.run(evaluation_time=evaluation_time)
# Out:
# 2025-03-13 16:30:55 [INFO] Applying time windows for evaluation time: 1741887000
# 2025-03-13 16:30:55 [INFO] Filtered to 7 time windows for 1741887000
# 2025-03-13 16:30:55 [INFO] Applied time windows to 487 POTIs
# 2025-03-13 16:30:55 [INFO] Running OPTICS clustering to obtain centres...
# 2025-03-13 16:30:55 [INFO] Using provided DataFrame
# 2025-03-13 16:30:55 [INFO] Loaded 487 points of interest
# 2025-03-13 16:30:55 [INFO] Running OPTICS clustering on 487 points
# 2025-03-13 16:30:55 [INFO] Using epsilon: 0.00018835321652671395 radians
# 2025-03-13 16:30:55 [INFO] Assigning noise points to nearest clusters using KNN
# 2025-03-13 16:30:55 [INFO] Found 31 clusters
# 2025-03-13 16:30:55 [INFO] Running KMeans with 31 OPTICS centres
# 2025-03-13 16:30:55 [INFO] Using provided DataFrame
# 2025-03-13 16:30:55 [INFO] Loaded 487 points of interest
# 2025-03-13 16:30:55 [INFO] Using provided DataFrame with 31 centers
# 2025-03-13 16:30:55 [INFO] Using vulnerability indices as sample weights
# 2025-03-13 16:30:55 [INFO] Starting K-means clustering with 31 clusters
# 2025-03-13 16:30:55 [INFO] Using predefined initialization method
# 2025-03-13 16:30:55 [INFO] Using predefined centroids
# 2025-03-13 16:30:55 [INFO] K-means iteration 1/300
# 2025-03-13 16:30:55 [INFO] Maximum centroid shift: 0.320944 km
# 2025-03-13 16:30:55 [INFO] K-means iteration 2/300
# 2025-03-13 16:30:55 [INFO] Maximum centroid shift: 0.159451 km
# 2025-03-13 16:30:55 [INFO] K-means iteration 3/300
# 2025-03-13 16:30:55 [INFO] Maximum centroid shift: 0.093247 km
# 2025-03-13 16:30:55 [INFO] K-means iteration 4/300
# 2025-03-13 16:30:55 [INFO] Maximum centroid shift: 0.070730 km
# 2025-03-13 16:30:55 [INFO] K-means iteration 5/300
# 2025-03-13 16:30:55 [INFO] Maximum centroid shift: 0.135136 km
# 2025-03-13 16:30:55 [INFO] K-means iteration 6/300
# 2025-03-13 16:30:55 [INFO] Maximum centroid shift: 0.068441 km
# 2025-03-13 16:30:55 [INFO] K-means iteration 7/300
# 2025-03-13 16:30:55 [INFO] Maximum centroid shift: 0.062269 km
# 2025-03-13 16:30:55 [INFO] K-means iteration 8/300
# 2025-03-13 16:30:55 [INFO] Maximum centroid shift: 0.000000 km
# 2025-03-13 16:30:55 [SUCCESS] Converged after 8 iterations
# 2025-03-13 16:30:55 [SUCCESS] K-means completed with inertia: 41.4011
# 2025-03-13 16:30:55 [INFO] Cluster distribution: {11: np.int64(25), 1: np.int64(22), 19: np.int64(21), 7: np.int64(21), 18: np.int64(21), 6: np.int64(19), 21: np.int64(19), 12: np.int64(19), 3: np.int64(19), 22: np.int64(19), 26: np.int64(18), 13: np.int64(17), 14: np.int64(17), 16: np.int64(15), 9: np.int64(15), 15: np.int64(15), 24: np.int64(14), 0: np.int64(14), 27: np.int64(14), 29: np.int64(14), 17: np.int64(14), 8: np.int64(14), 28: np.int64(13), 20: np.int64(12), 10: np.int64(12), 25: np.int64(12), 23: np.int64(12), 30: np.int64(10), 2: np.int64(10), 5: np.int64(10), 4: np.int64(10)}
# 2025-03-13 16:30:55 [INFO] Assigning zones to nearest clusters...
# 2025-03-13 16:30:55 [INFO] Calculating vulnerability using gaussian method...
# 2025-03-13 16:30:55 [INFO] Using calculated max vulnerability: 0.000220381042397232
# 2025-03-13 16:30:55 [INFO] Min VL: 1.4462165571635995e-05, Max VL: 0.000220381042397232
# 2025-03-13 16:30:55 [SUCCESS] Vulnerability calculated for 514 zones
# 2025-03-13 16:30:55 [INFO] Vulnerability statistics:
# 2025-03-13 16:30:55 [INFO] count    514.000000
# mean       0.557266
# std        0.218684
# min        0.000000
# 25%        0.429003
# 50%        0.568651
# 75%        0.708926
# max        1.000000
# Name: VL_normalized, dtype: float64
# 2025-03-13 16:30:55 [INFO] Smoothing vulnerability levels with influence threshold 0.3...
# 2025-03-13 16:30:56 [SUCCESS] Vulnerability smoothing complete
# 2025-03-13 16:30:56 [INFO] Smoothed vulnerability statistics:
# 2025-03-13 16:30:56 [INFO] count    514.000000
# mean       0.565695
# std        0.204710
# min        0.000000
# 25%        0.454874
# 50%        0.571979
# 75%        0.703904
# max        1.000000
# Name: VL_normalized_smoothed, dtype: float64

# %% [markdown]
# ## 7. Visualize results on a map

# %%
# Visualize the results
assessor.visualize()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9541836a0e7c23b4f3367fe6612ff66e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9541836a0e7c23b4f3367fe6612ff66e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9541836a0e7c23b4f3367fe6612ff66e = L.map(
#                 &quot;map_9541836a0e7c23b4f3367fe6612ff66e&quot;,
#                 {
#                     center: [41.15883084224236, -8.622108378791468],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2ff11a46d19f576e4fd0e3f68003df4 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c2ff11a46d19f576e4fd0e3f68003df4.addTo(map_9541836a0e7c23b4f3367fe6612ff66e);
#
#
#         function geo_json_ed79102534d1ff32c77b92a91d91d1c0_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;35&quot;:
#                     return {&quot;color&quot;: &quot;#feb953ff&quot;, &quot;fillColor&quot;: &quot;#feb953ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;1&quot;: case &quot;64&quot;: case &quot;188&quot;:
#                     return {&quot;color&quot;: &quot;#fecc67ff&quot;, &quot;fillColor&quot;: &quot;#fecc67ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;2&quot;: case &quot;205&quot;: case &quot;273&quot;:
#                     return {&quot;color&quot;: &quot;#fea647ff&quot;, &quot;fillColor&quot;: &quot;#fea647ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#fec662ff&quot;, &quot;fillColor&quot;: &quot;#fec662ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#fead49ff&quot;, &quot;fillColor&quot;: &quot;#fead49ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#feaa48ff&quot;, &quot;fillColor&quot;: &quot;#feaa48ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;6&quot;: case &quot;371&quot;:
#                     return {&quot;color&quot;: &quot;#fe9840ff&quot;, &quot;fillColor&quot;: &quot;#fe9840ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#feb751ff&quot;, &quot;fillColor&quot;: &quot;#feb751ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;8&quot;: case &quot;13&quot;: case &quot;387&quot;:
#                     return {&quot;color&quot;: &quot;#fe8e3cff&quot;, &quot;fillColor&quot;: &quot;#fe8e3cff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;9&quot;: case &quot;37&quot;: case &quot;124&quot;:
#                     return {&quot;color&quot;: &quot;#fd6c32ff&quot;, &quot;fillColor&quot;: &quot;#fd6c32ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;10&quot;: case &quot;23&quot;: case &quot;77&quot;: case &quot;190&quot;: case &quot;287&quot;: case &quot;368&quot;: case &quot;375&quot;:
#                     return {&quot;color&quot;: &quot;#fe933eff&quot;, &quot;fillColor&quot;: &quot;#fe933eff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;11&quot;: case &quot;40&quot;: case &quot;66&quot;: case &quot;199&quot;: case &quot;262&quot;: case &quot;366&quot;: case &quot;372&quot;: case &quot;374&quot;:
#                     return {&quot;color&quot;: &quot;#fe903dff&quot;, &quot;fillColor&quot;: &quot;#fe903dff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#feb650ff&quot;, &quot;fillColor&quot;: &quot;#feb650ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
