# %% [markdown]
# # VERUS Experimentation #1
#
# **Porto, Portugal**
#
# The experiment is reported on the article (under review). It describes the analysis of the city of Porto, Portugal using four different evaluation times. This notebook contains the code to reproduce the results following a step-by-step approach.
#
# The rationale for parameter selection, time window definition and evaluation times are available in the article.

# %%
from verus import VERUS
from verus.data import TimeWindowGenerator
from verus.grid import HexagonGridGenerator
import pandas as pd

# %% [markdown]
# ## 1. Data Preparation
#
# To ensure reproducibility, we will use a pre-fetched dataset.

# %%
poti_df = pd.read_csv("../../data/poti/porto_dataset_buffered.csv")
time_windows_df = pd.read_csv("../../data/time_windows/default_time_windows.csv")

# %% [markdown]
# ### 1.1. Generate vulnerability zones

# %%
grid_gen = HexagonGridGenerator(region="Porto, Portugal", edge_length=250)
hex_grid = grid_gen.run()
# Out:
# 2025-03-14 10:11:19 [INFO] Initialized grid generator for Porto, Portugal with 250m edge length
# 2025-03-14 10:11:19 [INFO] Processing region: Porto, Portugal
# 2025-03-14 10:11:19 [INFO] Generating hexagonal grid with edge length 250m
# 2025-03-14 10:11:19 [INFO] Generated 740 hexagons
# 2025-03-14 10:11:19 [INFO] Assigning random values between 0 and 1
# 2025-03-14 10:11:19 [INFO] Assigning colors based on values
# 2025-03-14 10:11:19 [INFO] Clipping grid to region boundaries
# 2025-03-14 10:11:19 [INFO] Clipped from 740 to 514 hexagons

# %% [markdown]
# ### 1.2. Initialize vulnerability assessment

# %%
# The maximum vulnerability corresponds to the maximum value among all
# the evaluation times. For a more consistent implementation, one shall
# compute the maximum vulnerability for each time window.
config = {
    "max_vulnerability": {"Porto": 0.0002668418580038524},
    "clustering": {
        "optics": {"min_samples": 5, "xi": 0.05, "min_cluster_size": 5},
        "kmeans": {"init": "predefined", "random_state": 42},
    },
}
assessor = VERUS(place_name="Porto", config=config)
# Out:
# 2025-03-14 10:32:01 [INFO] VulnerabilityAssessor initialized for Porto using gaussian method

# %% [markdown]
# ### 1.3. Load data

# %%
assessor.load(
    potis_df=poti_df,
    time_windows_df=time_windows_df,
    zones_gdf=hex_grid,
)
# The following warnings are expected since the data was not preprocessed.
# Out:
# 2025-03-14 10:32:02 [WARNING] POTI DataFrame doesn't have 'vi' column. Using default vi=1.
# 2025-03-14 10:32:02 [WARNING] POTI DataFrame doesn't have 'cluster' column. Setting all to 0.
# 2025-03-14 10:32:02 [INFO] Loaded 430 POTIs
# 2025-03-14 10:32:02 [INFO] Loaded 514 vulnerability zones
# 2025-03-14 10:32:02 [INFO] Loaded 108 time window entries

# %% [markdown]
# ## 2. Vulnerability Assessment

# %% [markdown]
# ### 2.1. Scenario 1

# %%
evaluation_time = TimeWindowGenerator.to_unix_epoch("2023-11-11 10:20:00")
results = assessor.run(evaluation_time=evaluation_time)
# Out:
# 2025-03-14 10:32:02 [INFO] Applying time windows for evaluation time: 1699698000
# 2025-03-14 10:32:02 [INFO] Filtered to 4 time windows for 1699698000
# 2025-03-14 10:32:02 [INFO] Applied time windows to 430 POTIs
# 2025-03-14 10:32:02 [INFO] Running OPTICS clustering to obtain centres...
# 2025-03-14 10:32:02 [INFO] Using provided DataFrame
# 2025-03-14 10:32:02 [INFO] Loaded 430 points of interest
# 2025-03-14 10:32:02 [INFO] Running OPTICS clustering on 430 points
# 2025-03-14 10:32:02 [INFO] Using epsilon: 0.00018835321652671395 radians
# 2025-03-14 10:32:02 [INFO] Assigning noise points to nearest clusters using KNN
# 2025-03-14 10:32:02 [INFO] Found 27 clusters
# 2025-03-14 10:32:02 [INFO] Running KMeans with 27 OPTICS centres
# 2025-03-14 10:32:02 [INFO] Using provided DataFrame
# 2025-03-14 10:32:02 [INFO] Loaded 430 points of interest
# 2025-03-14 10:32:02 [INFO] Using provided DataFrame with 27 centers
# 2025-03-14 10:32:02 [INFO] Using vulnerability indices as sample weights
# 2025-03-14 10:32:02 [INFO] Starting K-means clustering with 27 clusters
# 2025-03-14 10:32:02 [INFO] Using predefined initialization method
# 2025-03-14 10:32:02 [INFO] Using predefined centroids
# 2025-03-14 10:32:02 [INFO] K-means iteration 1/300
# 2025-03-14 10:32:02 [INFO] Maximum centroid shift: 0.632992 km
# 2025-03-14 10:32:02 [INFO] K-means iteration 2/300
# 2025-03-14 10:32:02 [INFO] Maximum centroid shift: 0.201350 km
# 2025-03-14 10:32:02 [INFO] K-means iteration 3/300
# 2025-03-14 10:32:02 [INFO] Maximum centroid shift: 0.106044 km
# 2025-03-14 10:32:02 [INFO] K-means iteration 4/300
# 2025-03-14 10:32:02 [INFO] Maximum centroid shift: 0.191569 km
# 2025-03-14 10:32:02 [INFO] K-means iteration 5/300
# 2025-03-14 10:32:02 [INFO] Maximum centroid shift: 0.169781 km
# 2025-03-14 10:32:02 [INFO] K-means iteration 6/300
# 2025-03-14 10:32:02 [INFO] Maximum centroid shift: 0.099653 km
# 2025-03-14 10:32:02 [INFO] K-means iteration 7/300
# 2025-03-14 10:32:02 [INFO] Maximum centroid shift: 0.000000 km
# 2025-03-14 10:32:02 [SUCCESS] Converged after 7 iterations
# 2025-03-14 10:32:02 [SUCCESS] K-means completed with inertia: 9.4354
# 2025-03-14 10:32:02 [INFO] Cluster distribution: {11: np.int64(23), 19: np.int64(22), 0: np.int64(20), 18: np.int64(20), 4: np.int64(19), 10: np.int64(19), 24: np.int64(19), 16: np.int64(18), 14: np.int64(17), 7: np.int64(17), 12: np.int64(17), 23: np.int64(17), 3: np.int64(17), 21: np.int64(16), 9: np.int64(16), 1: np.int64(16), 17: np.int64(15), 22: np.int64(15), 8: np.int64(14), 20: np.int64(14), 13: np.int64(13), 6: np.int64(13), 15: np.int64(12), 5: np.int64(12), 2: np.int64(11), 26: np.int64(9), 25: np.int64(9)}
# 2025-03-14 10:32:02 [INFO] Assigning zones to nearest clusters...
# 2025-03-14 10:32:02 [INFO] Calculating vulnerability using gaussian method...
# 2025-03-14 10:32:02 [INFO] Using configured max vulnerability: 0.0002668418580038524
# 2025-03-14 10:32:02 [INFO] Min VL: 0.0, Max VL: 0.0002668418580038524
# 2025-03-14 10:32:02 [SUCCESS] Vulnerability calculated for 514 zones
# 2025-03-14 10:32:02 [INFO] Vulnerability statistics:
# 2025-03-14 10:32:02 [INFO] count    514.000000
# mean       0.156238
# std        0.160652
# min        0.000000
# 25%        0.062877
# 50%        0.096793
# 75%        0.157440
# max        0.890253
# Name: VL_normalized, dtype: float64
# 2025-03-14 10:32:02 [INFO] Smoothing vulnerability levels with influence threshold 0.3...
# 2025-03-14 10:32:03 [SUCCESS] Vulnerability smoothing complete
# 2025-03-14 10:32:03 [INFO] Smoothed vulnerability statistics:
# 2025-03-14 10:32:03 [INFO] count    514.000000
# mean       0.160977
# std        0.157358
# min        0.000000
# 25%        0.069607
# 50%        0.101306
# 75%        0.185510
# max        0.883045
# Name: VL_normalized_smoothed, dtype: float64

# %% [markdown]
# **Map of the vulnerability zones**

# %%
# Visualize the results
assessor.visualize()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f625a797ce50be9f58788b2fad5fe95b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f625a797ce50be9f58788b2fad5fe95b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f625a797ce50be9f58788b2fad5fe95b = L.map(
#                 &quot;map_f625a797ce50be9f58788b2fad5fe95b&quot;,
#                 {
#                     center: [41.15859397060765, -8.620754162133954],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e02825f2be89e3bf4dc39e88ff8c48f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3e02825f2be89e3bf4dc39e88ff8c48f.addTo(map_f625a797ce50be9f58788b2fad5fe95b);
#
#
#         function geo_json_65603fcfa5bf52ca150a3687476b6b56_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;55&quot;: case &quot;141&quot;:
#                     return {&quot;color&quot;: &quot;#ffe186ff&quot;, &quot;fillColor&quot;: &quot;#ffe186ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fecb67ff&quot;, &quot;fillColor&quot;: &quot;#fecb67ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;2&quot;: case &quot;134&quot;: case &quot;135&quot;: case &quot;137&quot;: case &quot;138&quot;: case &quot;181&quot;: case &quot;191&quot;: case &quot;196&quot;: case &quot;205&quot;: case &quot;334&quot;: case &quot;341&quot;: case &quot;363&quot;: case &quot;402&quot;:
#                     return {&quot;color&quot;: &quot;#fff8b9ff&quot;, &quot;fillColor&quot;: &quot;#fff8b9ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;3&quot;: case &quot;4&quot;: case &quot;47&quot;: case &quot;125&quot;: case &quot;143&quot;: case &quot;146&quot;: case &quot;166&quot;: case &quot;168&quot;: case &quot;367&quot;: case &quot;368&quot;: case &quot;414&quot;: case &quot;498&quot;:
#                     return {&quot;color&quot;: &quot;#ffefa5ff&quot;, &quot;fillColor&quot;: &quot;#ffefa5ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;5&quot;: case &quot;396&quot;: case &quot;494&quot;:
#                     return {&quot;color&quot;: &quot;#fff5b4ff&quot;, &quot;fillColor&quot;: &quot;#fff5b4ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;6&quot;: case &quot;27&quot;: case &quot;43&quot;: case &quot;189&quot;: case &quot;275&quot;: case &quot;354&quot;: case &quot;370&quot;: case &quot;374&quot;: case &quot;422&quot;: case &quot;467&quot;: case &quot;505&quot;:
#                     return {&quot;color&quot;: &quot;#fff3aeff&quot;, &quot;fillColor&quot;: &quot;#fff3aeff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;7&quot;: case &quot;139&quot;: case &quot;153&quot;: case &quot;177&quot;: case &quot;202&quot;: case &quot;203&quot;: case &quot;343&quot;: case &quot;444&quot;: case &quot;507&quot;:
#                     return {&quot;color&quot;: &quot;#fff8baff&quot;, &quot;fillColor&quot;: &quot;#fff8baff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;8&quot;: case &quot;313&quot;: case &quot;340&quot;: case &quot;501&quot;:
#                     return {&quot;color&quot;: &quot;#fff6b4ff&quot;, &quot;fillColor&quot;: &quot;#fff6b4ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;9&quot;: case &quot;178&quot;: case &quot;223&quot;: case &quot;243&quot;: case &quot;301&quot;: case &quot;364&quot;: case &quot;375&quot;: case &quot;409&quot;: case &quot;445&quot;: case &quot;493&quot;: case &quot;506&quot;:
#                     return {&quot;color&quot;: &quot;#fff1a9ff&quot;, &quot;fillColor&quot;: &quot;#fff1a9ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;10&quot;: case &quot;30&quot;: case &quot

# %% [markdown]
# ### 2.2. Scenario 2

# %%
evaluation_time = TimeWindowGenerator.to_unix_epoch("2023-11-06 08:40:00")
results = assessor.run(evaluation_time=evaluation_time)
# Out:
# 2025-03-14 10:32:03 [INFO] Applying time windows for evaluation time: 1699260000
# 2025-03-14 10:32:03 [INFO] Filtered to 6 time windows for 1699260000
# 2025-03-14 10:32:03 [INFO] Applied time windows to 430 POTIs
# 2025-03-14 10:32:03 [INFO] Running OPTICS clustering to obtain centres...
# 2025-03-14 10:32:03 [INFO] Using provided DataFrame
# 2025-03-14 10:32:03 [INFO] Loaded 430 points of interest
# 2025-03-14 10:32:03 [INFO] Running OPTICS clustering on 430 points
# 2025-03-14 10:32:03 [INFO] Using epsilon: 0.00018835321652671395 radians
# 2025-03-14 10:32:03 [INFO] Assigning noise points to nearest clusters using KNN
# 2025-03-14 10:32:03 [INFO] Found 27 clusters
# 2025-03-14 10:32:03 [INFO] Running KMeans with 27 OPTICS centres
# 2025-03-14 10:32:03 [INFO] Using provided DataFrame
# 2025-03-14 10:32:03 [INFO] Loaded 430 points of interest
# 2025-03-14 10:32:03 [INFO] Using provided DataFrame with 27 centers
# 2025-03-14 10:32:03 [INFO] Using vulnerability indices as sample weights
# 2025-03-14 10:32:03 [INFO] Starting K-means clustering with 27 clusters
# 2025-03-14 10:32:03 [INFO] Using predefined initialization method
# 2025-03-14 10:32:03 [INFO] Using predefined centroids
# 2025-03-14 10:32:03 [INFO] K-means iteration 1/300
# 2025-03-14 10:32:03 [INFO] Maximum centroid shift: 0.165257 km
# 2025-03-14 10:32:03 [INFO] K-means iteration 2/300
# 2025-03-14 10:32:03 [INFO] Maximum centroid shift: 0.186761 km
# 2025-03-14 10:32:03 [INFO] K-means iteration 3/300
# 2025-03-14 10:32:03 [INFO] Maximum centroid shift: 0.177731 km
# 2025-03-14 10:32:03 [INFO] K-means iteration 4/300
# 2025-03-14 10:32:03 [INFO] Maximum centroid shift: 0.121310 km
# 2025-03-14 10:32:03 [INFO] K-means iteration 5/300
# 2025-03-14 10:32:03 [INFO] Maximum centroid shift: 0.026333 km
# 2025-03-14 10:32:03 [INFO] K-means iteration 6/300
# 2025-03-14 10:32:03 [INFO] Maximum centroid shift: 0.000000 km
# 2025-03-14 10:32:03 [SUCCESS] Converged after 6 iterations
# 2025-03-14 10:32:03 [SUCCESS] K-means completed with inertia: 58.0387
# 2025-03-14 10:32:03 [INFO] Cluster distribution: {18: np.int64(22), 10: np.int64(22), 16: np.int64(21), 14: np.int64(21), 19: np.int64(21), 0: np.int64(20), 7: np.int64(19), 22: np.int64(19), 3: np.int64(19), 1: np.int64(18), 4: np.int64(18), 13: np.int64(17), 11: np.int64(17), 12: np.int64(16), 24: np.int64(16), 23: np.int64(15), 6: np.int64(13), 26: np.int64(13), 20: np.int64(13), 5: np.int64(12), 8: np.int64(12), 2: np.int64(12), 15: np.int64(12), 21: np.int64(12), 17: np.int64(11), 9: np.int64(10), 25: np.int64(9)}
# 2025-03-14 10:32:03 [INFO] Assigning zones to nearest clusters...
# 2025-03-14 10:32:03 [INFO] Calculating vulnerability using gaussian method...
# 2025-03-14 10:32:03 [INFO] Using configured max vulnerability: 0.0002668418580038524
# 2025-03-14 10:32:03 [INFO] Min VL: 2.607850517368001e-05, Max VL: 0.0002668418580038524
# 2025-03-14 10:32:03 [SUCCESS] Vulnerability calculated for 514 zones
# 2025-03-14 10:32:03 [INFO] Vulnerability statistics:
# 2025-03-14 10:32:03 [INFO] count    514.000000
# mean       0.506115
# std        0.184793
# min        0.000000
# 25%        0.386091
# 50%        0.481829
# 75%        0.597817
# max        1.000000
# Name: VL_normalized, dtype: float64
# 2025-03-14 10:32:03 [INFO] Smoothing vulnerability levels with influence threshold 0.3...
# 2025-03-14 10:32:04 [SUCCESS] Vulnerability smoothing complete
# 2025-03-14 10:32:04 [INFO] Smoothed vulnerability statistics:
# 2025-03-14 10:32:04 [INFO] count    514.000000
# mean       0.514463
# std        0.173877
# min        0.000000
# 25%        0.401130
# 50%        0.489444
# 75%        0.597528
# max        1.000000
# Name: VL_normalized_smoothed, dtype: float64

# %% [markdown]
# **Map of the vulnerability zones**

# %%
# Visualize the results
assessor.visualize()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4db4ca78909182bd24d225115fc13d43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4db4ca78909182bd24d225115fc13d43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4db4ca78909182bd24d225115fc13d43 = L.map(
#                 &quot;map_4db4ca78909182bd24d225115fc13d43&quot;,
#                 {
#                     center: [41.15859397060765, -8.620754162133954],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c4e1f4132b6877fd26393bf6d0def1b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c4e1f4132b6877fd26393bf6d0def1b.addTo(map_4db4ca78909182bd24d225115fc13d43);
#
#
#         function geo_json_bf04e272ec90acdaff8a4e9077409a75_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;205&quot;: case &quot;365&quot;:
#                     return {&quot;color&quot;: &quot;#fec05bff&quot;, &quot;fillColor&quot;: &quot;#fec05bff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;1&quot;: case &quot;503&quot;:
#                     return {&quot;color&quot;: &quot;#febc56ff&quot;, &quot;fillColor&quot;: &quot;#febc56ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#ffdc7bff&quot;, &quot;fillColor&quot;: &quot;#ffdc7bff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;3&quot;: case &quot;399&quot;:
#                     return {&quot;color&quot;: &quot;#ffdf82ff&quot;, &quot;fillColor&quot;: &quot;#ffdf82ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#ffe185ff&quot;, &quot;fillColor&quot;: &quot;#ffe185ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#ffe289ff&quot;, &quot;fillColor&quot;: &quot;#ffe289ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#fed471ff&quot;, &quot;fillColor&quot;: &quot;#fed471ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#ffdb7aff&quot;, &quot;fillColor&quot;: &quot;#ffdb7aff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;8&quot;: case &quot;331&quot;: case &quot;449&quot;:
#                     return {&quot;color&quot;: &quot;#fec762ff&quot;, &quot;fillColor&quot;: &quot;#fec762ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;9&quot;: case &quot;201&quot;: case &quot;398&quot;:
#                     return {&quot;color&quot;: &quot;#febf59ff&quot;, &quot;fillColor&quot;: &quot;#febf59ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#fecf6aff&quot;, &quot;fillColor&quot;: &quot;#fecf6aff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#ffe083ff&quot;, &quot;fillColor&quot;: &quot;#ffe083ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;12&quot;: case &quot;374&quot;: case &quot;379&quot;:
#                     return {&quot;color&quot;: &quot;#fea948ff&quot;, &quot;fillColor&quot;: &quot;#fea948ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;13&quot;: case &quot;368&quot;:
#                     return {&quot;color&quot;: &quot;#fd863aff&quot;, &quot;fillColor&quot;: &quot;#fd863aff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;14&quot;:

# %% [markdown]
# ### 2.3. Scenario 3

# %%
evaluation_time = TimeWindowGenerator.to_unix_epoch("2023-11-06 12:30:00")
results = assessor.run(evaluation_time=evaluation_time)
# Out:
# 2025-03-14 10:32:04 [INFO] Applying time windows for evaluation time: 1699273800
# 2025-03-14 10:32:04 [INFO] Filtered to 7 time windows for 1699273800
# 2025-03-14 10:32:04 [INFO] Applied time windows to 430 POTIs
# 2025-03-14 10:32:04 [INFO] Running OPTICS clustering to obtain centres...
# 2025-03-14 10:32:04 [INFO] Using provided DataFrame
# 2025-03-14 10:32:04 [INFO] Loaded 430 points of interest
# 2025-03-14 10:32:04 [INFO] Running OPTICS clustering on 430 points
# 2025-03-14 10:32:04 [INFO] Using epsilon: 0.00018835321652671395 radians
# 2025-03-14 10:32:04 [INFO] Assigning noise points to nearest clusters using KNN
# 2025-03-14 10:32:04 [INFO] Found 27 clusters
# 2025-03-14 10:32:04 [INFO] Running KMeans with 27 OPTICS centres
# 2025-03-14 10:32:04 [INFO] Using provided DataFrame
# 2025-03-14 10:32:04 [INFO] Loaded 430 points of interest
# 2025-03-14 10:32:04 [INFO] Using provided DataFrame with 27 centers
# 2025-03-14 10:32:04 [INFO] Using vulnerability indices as sample weights
# 2025-03-14 10:32:04 [INFO] Starting K-means clustering with 27 clusters
# 2025-03-14 10:32:04 [INFO] Using predefined initialization method
# 2025-03-14 10:32:04 [INFO] Using predefined centroids
# 2025-03-14 10:32:04 [INFO] K-means iteration 1/300
# 2025-03-14 10:32:04 [INFO] Maximum centroid shift: 0.186567 km
# 2025-03-14 10:32:04 [INFO] K-means iteration 2/300
# 2025-03-14 10:32:04 [INFO] Maximum centroid shift: 0.184586 km
# 2025-03-14 10:32:04 [INFO] K-means iteration 3/300
# 2025-03-14 10:32:04 [INFO] Maximum centroid shift: 0.131337 km
# 2025-03-14 10:32:04 [INFO] K-means iteration 4/300
# 2025-03-14 10:32:04 [INFO] Maximum centroid shift: 0.122198 km
# 2025-03-14 10:32:04 [INFO] K-means iteration 5/300
# 2025-03-14 10:32:04 [INFO] Maximum centroid shift: 0.067270 km
# 2025-03-14 10:32:04 [INFO] K-means iteration 6/300
# 2025-03-14 10:32:04 [INFO] Maximum centroid shift: 0.106833 km
# 2025-03-14 10:32:04 [INFO] K-means iteration 7/300
# 2025-03-14 10:32:04 [INFO] Maximum centroid shift: 0.338321 km
# 2025-03-14 10:32:04 [INFO] K-means iteration 8/300
# 2025-03-14 10:32:04 [INFO] Maximum centroid shift: 0.025474 km
# 2025-03-14 10:32:04 [INFO] K-means iteration 9/300
# 2025-03-14 10:32:04 [INFO] Maximum centroid shift: 0.000000 km
# 2025-03-14 10:32:04 [SUCCESS] Converged after 9 iterations
# 2025-03-14 10:32:04 [SUCCESS] K-means completed with inertia: 42.7609
# 2025-03-14 10:32:04 [INFO] Cluster distribution: {19: np.int64(23), 14: np.int64(22), 10: np.int64(22), 0: np.int64(21), 18: np.int64(20), 4: np.int64(20), 1: np.int64(19), 7: np.int64(19), 12: np.int64(19), 3: np.int64(19), 22: np.int64(18), 16: np.int64(18), 23: np.int64(17), 24: np.int64(17), 11: np.int64(16), 13: np.int64(14), 6: np.int64(13), 26: np.int64(13), 17: np.int64(13), 21: np.int64(13), 20: np.int64(13), 8: np.int64(12), 2: np.int64(12), 5: np.int64(12), 9: np.int64(10), 25: np.int64(9), 15: np.int64(6)}
# 2025-03-14 10:32:04 [INFO] Assigning zones to nearest clusters...
# 2025-03-14 10:32:04 [INFO] Calculating vulnerability using gaussian method...
# 2025-03-14 10:32:04 [INFO] Using configured max vulnerability: 0.0002668418580038524
# 2025-03-14 10:32:04 [INFO] Min VL: 3.44476563006471e-05, Max VL: 0.0002668418580038524
# 2025-03-14 10:32:04 [SUCCESS] Vulnerability calculated for 514 zones
# 2025-03-14 10:32:04 [INFO] Vulnerability statistics:
# 2025-03-14 10:32:04 [INFO] count    514.000000
# mean       0.357390
# std        0.139642
# min        0.000000
# 25%        0.255978
# 50%        0.354383
# 75%        0.462270
# max        0.678228
# Name: VL_normalized, dtype: float64
# 2025-03-14 10:32:04 [INFO] Smoothing vulnerability levels with influence threshold 0.3...
# 2025-03-14 10:32:05 [SUCCESS] Vulnerability smoothing complete
# 2025-03-14 10:32:05 [INFO] Smoothed vulnerability statistics:
# 2025-03-14 10:32:05 [INFO] count    514.000000
# mean       0.362702
# std        0.131689
# min        0.000000
# 25%        0.266313
# 50%        0.358622
# 75%        0.462063
# max        0.651746
# Name: VL_normalized_smoothed, dtype: float64

# %% [markdown]
# **Map of the vulnerability zones**

# %%
# Visualize the results
assessor.visualize()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_629b2e4c4082184e2687c43384c68e68 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_629b2e4c4082184e2687c43384c68e68&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_629b2e4c4082184e2687c43384c68e68 = L.map(
#                 &quot;map_629b2e4c4082184e2687c43384c68e68&quot;,
#                 {
#                     center: [41.15859397060765, -8.620754162133954],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86264b318c9f3adf9be3812495ae0646 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_86264b318c9f3adf9be3812495ae0646.addTo(map_629b2e4c4082184e2687c43384c68e68);
#
#
#         function geo_json_6b7b0fd0be144f54da3a05af90e59337_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;419&quot;: case &quot;451&quot;: case &quot;488&quot;:
#                     return {&quot;color&quot;: &quot;#ffe084ff&quot;, &quot;fillColor&quot;: &quot;#ffe084ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;1&quot;: case &quot;365&quot;: case &quot;504&quot;:
#                     return {&quot;color&quot;: &quot;#ffdd7dff&quot;, &quot;fillColor&quot;: &quot;#ffdd7dff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#ffe894ff&quot;, &quot;fillColor&quot;: &quot;#ffe894ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;3&quot;: case &quot;199&quot;: case &quot;398&quot;:
#                     return {&quot;color&quot;: &quot;#ffe793ff&quot;, &quot;fillColor&quot;: &quot;#ffe793ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#fff2aaff&quot;, &quot;fillColor&quot;: &quot;#fff2aaff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;5&quot;: case &quot;396&quot;: case &quot;450&quot;:
#                     return {&quot;color&quot;: &quot;#ffea99ff&quot;, &quot;fillColor&quot;: &quot;#ffea99ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;6&quot;: case &quot;168&quot;: case &quot;198&quot;:
#                     return {&quot;color&quot;: &quot;#ffdd7eff&quot;, &quot;fillColor&quot;: &quot;#ffdd7eff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;7&quot;: case &quot;18&quot;: case &quot;26&quot;: case &quot;180&quot;:
#                     return {&quot;color&quot;: &quot;#ffe690ff&quot;, &quot;fillColor&quot;: &quot;#ffe690ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;8&quot;: case &quot;190&quot;: case &quot;206&quot;:
#                     return {&quot;color&quot;: &quot;#ffdb7aff&quot;, &quot;fillColor&quot;: &quot;#ffdb7aff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;9&quot;: case &quot;243&quot;: case &quot;331&quot;: case &quot;393&quot;: case &quot;427&quot;: case &quot;431&quot;: case &quot;461&quot;:
#                     return {&quot;color&quot;: &quot;#fec762ff&quot;, &quot;fillColor&quot;: &quot;#fec762ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;10&quot;: case &quot;433&quot;: case &quot;443&quot;:
#                     return {&quot;color&quot;: &quot;#fed976ff&quot;, &quot;fillColor&quot;: &quot;#fed976ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;11&quot;: case &quot;364&quot;:
#                     return {&quot;color&quot;: &quot;#ffdc7cff&quot;, &quot;fillColor&quot;: &quot;#ffdc7cff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;12&quot;: case &quot;30&quot;: case &quot;323&quot;: case &quot;332&quot;: case &quot;474&quot;: case &quot;489&quot;:

# %% [markdown]
# ### 2.4. Scenario 4

# %%
evaluation_time = TimeWindowGenerator.to_unix_epoch("2023-11-06 17:30:00")
results = assessor.run(evaluation_time=evaluation_time)
# Out:
# 2025-03-14 10:32:05 [INFO] Applying time windows for evaluation time: 1699291800
# 2025-03-14 10:32:05 [INFO] Filtered to 7 time windows for 1699291800
# 2025-03-14 10:32:05 [INFO] Applied time windows to 430 POTIs
# 2025-03-14 10:32:05 [INFO] Running OPTICS clustering to obtain centres...
# 2025-03-14 10:32:05 [INFO] Using provided DataFrame
# 2025-03-14 10:32:05 [INFO] Loaded 430 points of interest
# 2025-03-14 10:32:05 [INFO] Running OPTICS clustering on 430 points
# 2025-03-14 10:32:05 [INFO] Using epsilon: 0.00018835321652671395 radians
# 2025-03-14 10:32:05 [INFO] Assigning noise points to nearest clusters using KNN
# 2025-03-14 10:32:05 [INFO] Found 27 clusters
# 2025-03-14 10:32:05 [INFO] Running KMeans with 27 OPTICS centres
# 2025-03-14 10:32:05 [INFO] Using provided DataFrame
# 2025-03-14 10:32:05 [INFO] Loaded 430 points of interest
# 2025-03-14 10:32:05 [INFO] Using provided DataFrame with 27 centers
# 2025-03-14 10:32:05 [INFO] Using vulnerability indices as sample weights
# 2025-03-14 10:32:05 [INFO] Starting K-means clustering with 27 clusters
# 2025-03-14 10:32:05 [INFO] Using predefined initialization method
# 2025-03-14 10:32:05 [INFO] Using predefined centroids
# 2025-03-14 10:32:05 [INFO] K-means iteration 1/300
# 2025-03-14 10:32:05 [INFO] Maximum centroid shift: 0.165257 km
# 2025-03-14 10:32:05 [INFO] K-means iteration 2/300
# 2025-03-14 10:32:05 [INFO] Maximum centroid shift: 0.171250 km
# 2025-03-14 10:32:05 [INFO] K-means iteration 3/300
# 2025-03-14 10:32:05 [INFO] Maximum centroid shift: 0.158733 km
# 2025-03-14 10:32:05 [INFO] K-means iteration 4/300
# 2025-03-14 10:32:05 [INFO] Maximum centroid shift: 0.098569 km
# 2025-03-14 10:32:05 [INFO] K-means iteration 5/300
# 2025-03-14 10:32:05 [INFO] Maximum centroid shift: 0.171208 km
# 2025-03-14 10:32:05 [INFO] K-means iteration 6/300
# 2025-03-14 10:32:05 [INFO] Maximum centroid shift: 0.123498 km
# 2025-03-14 10:32:05 [INFO] K-means iteration 7/300
# 2025-03-14 10:32:05 [INFO] Maximum centroid shift: 0.081733 km
# 2025-03-14 10:32:05 [INFO] K-means iteration 8/300
# 2025-03-14 10:32:05 [INFO] Maximum centroid shift: 0.150443 km
# 2025-03-14 10:32:05 [INFO] K-means iteration 9/300
# 2025-03-14 10:32:05 [INFO] Maximum centroid shift: 0.113910 km
# 2025-03-14 10:32:05 [INFO] K-means iteration 10/300
# 2025-03-14 10:32:05 [INFO] Maximum centroid shift: 0.133883 km
# 2025-03-14 10:32:05 [INFO] K-means iteration 11/300
# 2025-03-14 10:32:05 [INFO] Maximum centroid shift: 0.081992 km
# 2025-03-14 10:32:05 [INFO] K-means iteration 12/300
# 2025-03-14 10:32:05 [INFO] Maximum centroid shift: 0.121833 km
# 2025-03-14 10:32:05 [INFO] K-means iteration 13/300
# 2025-03-14 10:32:05 [INFO] Maximum centroid shift: 0.031967 km
# 2025-03-14 10:32:05 [INFO] K-means iteration 14/300
# 2025-03-14 10:32:05 [INFO] Maximum centroid shift: 0.098270 km
# 2025-03-14 10:32:05 [INFO] K-means iteration 15/300
# 2025-03-14 10:32:05 [INFO] Maximum centroid shift: 0.096232 km
# 2025-03-14 10:32:05 [INFO] K-means iteration 16/300
# 2025-03-14 10:32:05 [INFO] Maximum centroid shift: 0.093568 km
# 2025-03-14 10:32:05 [INFO] K-means iteration 17/300
# 2025-03-14 10:32:05 [INFO] Maximum centroid shift: 0.000000 km
# 2025-03-14 10:32:05 [SUCCESS] Converged after 17 iterations
# 2025-03-14 10:32:05 [SUCCESS] K-means completed with inertia: 57.6856
# 2025-03-14 10:32:05 [INFO] Cluster distribution: {18: np.int64(22), 10: np.int64(22), 0: np.int64(21), 14: np.int64(21), 19: np.int64(21), 7: np.int64(20), 4: np.int64(19), 22: np.int64(19), 3: np.int64(19), 16: np.int64(18), 11: np.int64(18), 1: np.int64(17), 12: np.int64(16), 24: np.int64(16), 17: np.int64(15), 20: np.int64(14), 15: np.int64(13), 13: np.int64(13), 9: np.int64(12), 6: np.int64(12), 26: np.int64(12), 25: np.int64(12), 8: np.int64(12), 21: np.int64(12), 5: np.int64(12), 23: np.int64(11), 2: np.int64(11)}
# 2025-03-14 10:32:05 [INFO] Assigning zones to nearest clusters...
# 2025-03-14 10:32:05 [INFO] Calculating vulnerability using gaussian method...
# 2025-03-14 10:32:05 [INFO] Using configured max vulnerability: 0.0002668418580038524
# 2025-03-14 10:32:05 [INFO] Min VL: 3.188194980388373e-05, Max VL: 0.0002668418580038524
# 2025-03-14 10:32:05 [SUCCESS] Vulnerability calculated for 514 zones
# 2025-03-14 10:32:05 [INFO] Vulnerability statistics:
# 2025-03-14 10:32:05 [INFO] count    514.000000
# mean       0.506250
# std        0.161777
# min        0.000000
# 25%        0.411747
# 50%        0.498655
# 75%        0.600736
# max        0.974000
# Name: VL_normalized, dtype: float64
# 2025-03-14 10:32:05 [INFO] Smoothing vulnerability levels with influence threshold 0.3...
# 2025-03-14 10:32:06 [SUCCESS] Vulnerability smoothing complete
# 2025-03-14 10:32:06 [INFO] Smoothed vulnerability statistics:
# 2025-03-14 10:32:06 [INFO] count    514.000000
# mean       0.514632
# std        0.149894
# min        0.000000
# 25%        0.431783
# 50%        0.514066
# 75%        0.601214
# max        0.970439
# Name: VL_normalized_smoothed, dtype: float64

# %% [markdown]
# **Map of the vulnerability zones**

# %%
# Visualize the results
assessor.visualize()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_400ad6cc68a9192b1a0059c0b3a41853 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_400ad6cc68a9192b1a0059c0b3a41853&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_400ad6cc68a9192b1a0059c0b3a41853 = L.map(
#                 &quot;map_400ad6cc68a9192b1a0059c0b3a41853&quot;,
#                 {
#                     center: [41.15859397060765, -8.620754162133954],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f5de6bbc3f69aa60b467110b9129c0aa = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f5de6bbc3f69aa60b467110b9129c0aa.addTo(map_400ad6cc68a9192b1a0059c0b3a41853);
#
#
#         function geo_json_63cf5fdf7887cd22524ac9d5674ede15_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#fecc68ff&quot;, &quot;fillColor&quot;: &quot;#fecc68ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fed06cff&quot;, &quot;fillColor&quot;: &quot;#fed06cff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;2&quot;: case &quot;165&quot;:
#                     return {&quot;color&quot;: &quot;#ffdd7eff&quot;, &quot;fillColor&quot;: &quot;#ffdd7eff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#ffda77ff&quot;, &quot;fillColor&quot;: &quot;#ffda77ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#ffe38aff&quot;, &quot;fillColor&quot;: &quot;#ffe38aff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;5&quot;: case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#ffdc7cff&quot;, &quot;fillColor&quot;: &quot;#ffdc7cff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;6&quot;: case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;#fec45fff&quot;, &quot;fillColor&quot;: &quot;#fec45fff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#fed16dff&quot;, &quot;fillColor&quot;: &quot;#fed16dff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;9&quot;: case &quot;140&quot;:
#                     return {&quot;color&quot;: &quot;#fea747ff&quot;, &quot;fillColor&quot;: &quot;#fea747ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;10&quot;: case &quot;39&quot;: case &quot;397&quot;:
#                     return {&quot;color&quot;: &quot;#feba54ff&quot;, &quot;fillColor&quot;: &quot;#feba54ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#feca65ff&quot;, &quot;fillColor&quot;: &quot;#feca65ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#febc57ff&quot;, &quot;fillColor&quot;: &quot;#febc57ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;13&quot;: case &quot;46&quot;: case &quot;200&quot;: case &quot;263&quot;: case &quot;338&quot;: case &quot;374&quot;: case &quot;385&quot;: case &quot;390&quot;: case &quot;488&quot;:
#                     return {&quot;color&quot;: &quot;#fe9b42ff&quot;, &quot;fillColor&quot;: &quot;#fe9b42ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 0.1};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;#ffdb7aff&quot;, &quot;fillColor&quot;: &quot;#ffdb7aff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weigh
